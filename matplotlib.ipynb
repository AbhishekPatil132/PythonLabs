# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.shape
# Out:
# (17000, 9)

# %% [markdown]
# **Age vs Income**

# %%
# plotting the graph using 'plot'
x = df["housing_median_age"]
y = df["median_income"]
plt.plot(x,y)
plt.title("Age vs Income graph")
plt.xlabel("Median Age")
plt.ylabel("Median Income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plotting the graph using 'bar'
x = df["housing_median_age"]
y = df["median_income"]
plt.bar(x,y)
plt.title("Age vs Income graph")
plt.xlabel("Median Age")
plt.ylabel("Median Income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 17000 artists>

# %%
# plotting the graph using 'scatter'
x = df["housing_median_age"]
y = df["median_income"]
plt.scatter(x,y)
plt.title("Age vs Income graph")
plt.xlabel("Median Age")
plt.ylabel("Median Income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plotting the graph using 'stem'
x = df["housing_median_age"]
y = df["median_income"]
plt.stem(x,y)
plt.title("Age vs Income graph")
plt.xlabel("Median Age")
plt.ylabel("Median Income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Median Income vs Households**

# %%
# plotting the graph using 'scatter'
x = df["median_income"]
y = df["households"]
plt.scatter(x,y)
plt.title("Income vs Househlds graph")
plt.xlabel("Median Income")
plt.ylabel("Households")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plotting the graph using 'bar'
x = df["median_income"]
y = df["households"]
plt.bar(x,y)
plt.title("Income vs Househlds graph")
plt.xlabel("Median Income")
plt.ylabel("Households")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plotting the graph using 'plot'
x = df["median_income"]
y = df["households"]
plt.plot(x,y)
plt.title("Income vs Househlds graph")
plt.xlabel("Median Income")
plt.ylabel("Households")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plotting the graph using 'stem'
x = df["median_income"]
y = df["households"]
plt.stem(x,y)
plt.title("Income vs Househlds graph")
plt.xlabel("Median Income")
plt.ylabel("Households")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Other basic graphs**

# %%
#implementing the pie graph
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7bed3b5d4be0>,
# ...
#  [Text(0.9801071672559598, 0.4993895680663527, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')],
#  [Text(0.5346039094123416, 0.2723943098543742, '15.0%'),
#   Text(-0.18541023936624987, 0.5706338958896061, '30.0%'),
#   Text(-0.27239425980114257, -0.5346039349157352, '45.0%'),
#   Text(0.5706339175888016, -0.18541017258299716, '10.0%')])

# %%
#using 'explode' parameter in pie
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explodes = (0.2, 0, 0, 0)
plt.pie(sizes, labels=labels, autopct="%1.1f%%", explode= explodes)
# Out:
# ([<matplotlib.patches.Wedge at 0x7bed3b438760>,
# ...
#  [Text(1.158308470393407, 0.5901876713511441, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')],
#  [Text(0.7128052125497888, 0.3631924131391656, '15.0%'),
#   Text(-0.18541023936624987, 0.5706338958896061, '30.0%'),
#   Text(-0.27239425980114257, -0.5346039349157352, '45.0%'),
#   Text(0.5706339175888016, -0.18541017258299716, '10.0%')])

# %%
bgmi = pd.read_csv('/content/Pubg_Stats.csv')
bgmi.head(20)
# Out:
#     Unnamed: 0    Player_Name  Matches_Played  Kills  Deaths  Assists  \
# 0            0  StealthMaster             250    587     143       98
# 1            1     SniperLion             312    823     218      112
# 2            2     NinjaGamer             186    492      84       56
# 3            3  ThunderStrike             409    923     267      134
# 4            4     SpeedDemon             143    368      68       42
# 5            5      BlazeFury             288    642     156       74
# 6            6    RapidShadow             201    539      93       68
# 7            7      Frostbite             178    421     105       63
# 8            8    SavageQueen             332    748     193      122
# 9            9   SwiftStriker             194    511      87       58
# 10          10  VenomousViper             210    566     132       71
# 11          11    PhoenixFury             288    742     188      104
# ...

# %%
x = bgmi['Rank']
y = bgmi['Kills']

plt.bar(x, y)
# Out:
# <BarContainer object of 221 artists>

# %%
x = bgmi['Time_Survived']
plt.ylabel("Time survived")
plt.violinplot(x,showmeans=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7bed3c3e69e0>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x7bed3c3e5f60>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7bed3c1993c0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7bed3c198100>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7bed3c19bee0>}

# %%
x = bgmi['Rank']
y= bgmi['Damage_Dealt']
plt.scatter(x,y)
# Out:
# <ipython-input-37-cb5d388ac0b2>:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y, cmap="magma")

# %%
#creating data matrix
matrix = bgmi.corr()
matrix
# Out:
# <ipython-input-38-d17ca3b4125a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = bgmi.corr()
#                    Unnamed: 0  Matches_Played     Kills    Deaths   Assists  \
# Unnamed: 0           1.000000       -0.065546  0.005367  0.007638  0.174565
# Matches_Played      -0.065546        1.000000  0.969942  0.951848  0.888980
# Kills                0.005367        0.969942  1.000000  0.975833  0.931733
# Deaths               0.007638        0.951848  0.975833  1.000000  0.942156
# Assists              0.174565        0.888980  0.931733  0.942156  1.000000
# Damage_Dealt         0.036636        0.943678  0.981199  0.966610  0.934713
# Headshots            0.082428        0.884856  0.933143  0.929560  0.900181
# Wins                 0.003196        0.946748  0.959834  0.941585  0.894324
# ...

# %%
import seaborn as sns
sns.heatmap(matrix, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
#using pivot table
data = bgmi.head(15)
ranks = bgmi['Ranks']
data_new = data.pivot_table(index=ranks, columns='Player_Name', values="Kills")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ranks'
#
# The above exception was the direct cause of the following exception:
#
# ...
